# %% [markdown]
# **Importation of Necessary Libraries**

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7864\687462750.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\User\Downloads\car_prices.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
data.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %% [markdown]
# **- Conversion to datetime**

# %%
data['year'] = pd.to_datetime(data['year'],format='%Y')

# %%
data.head()
# Out:
#         year   make                model        trim   body transmission  \
# 0 2015-01-01    Kia              Sorento          LX    SUV    automatic
# 1 2015-01-01    Kia              Sorento          LX    SUV    automatic
# 2 2014-01-01    BMW             3 Series  328i SULEV  Sedan    automatic
# 3 2015-01-01  Volvo                  S60          T5  Sedan    automatic
# 4 2014-01-01    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
data['saledate']
# Out:
# 0         Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1         Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 2         Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
# 3         Thu Jan 29 2015 04:30:00 GMT-0800 (PST)
# 4         Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
#                            ...
# 558832    Thu Jul 09 2015 07:00:00 GMT-0700 (PDT)
# 558833    Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558834    Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
# 558835    Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)
# 558836    Thu May 28 2015 05:30:00 GMT-0700 (PDT)
# Name: saledate, Length: 558837, dtype: object

# %%
data['parsed_date'] = pd.to_datetime(data['saledate'], utc=True, errors='coerce')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7864\3057345391.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['parsed_date'] = pd.to_datetime(data['saledate'], utc=True, errors='coerce')

# %%
data.head()
# Out:
#         year   make                model        trim   body transmission  \
# 0 2015-01-01    Kia              Sorento          LX    SUV    automatic
# 1 2015-01-01    Kia              Sorento          LX    SUV    automatic
# 2 2014-01-01    BMW             3 Series  328i SULEV  Sedan    automatic
# 3 2015-01-01  Volvo                  S60          T5  Sedan    automatic
# 4 2014-01-01    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
data.columns
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate', 'parsed_date'],
#       dtype='object')

# %% [markdown]
# **EDA using Visualizations**

# %%
data['sale_year'] = data['saledate'].str.split(expand=True)[3]
data['sale_month'] = data['saledate'].str.split(expand=True)[1]

# %%
data.head()
# Out:
#         year   make                model        trim   body transmission  \
# 0 2015-01-01    Kia              Sorento          LX    SUV    automatic
# 1 2015-01-01    Kia              Sorento          LX    SUV    automatic
# 2 2014-01-01    BMW             3 Series  328i SULEV  Sedan    automatic
# 3 2015-01-01  Volvo                  S60          T5  Sedan    automatic
# 4 2014-01-01    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
data['sale_year'] = data['sale_year'].fillna(0)
data['year'] = data['year'].fillna(0)

# %%
data['Age at Sale'] = data['sale_year'].astype('int') - data['year'].astype('int64')

# %%
data['year'] = pd.to_datetime(data['year'],format='%Y')

# %%
data['parsed_date'] = pd.to_datetime(data['saledate'], utc=True, errors='coerce')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7864\3057345391.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['parsed_date'] = pd.to_datetime(data['saledate'], utc=True, errors='coerce')

# %%
data.head()
# Out:
#         year   make                model        trim   body transmission  \
# 0 2015-01-01    Kia              Sorento          LX    SUV    automatic
# 1 2015-01-01    Kia              Sorento          LX    SUV    automatic
# 2 2014-01-01    BMW             3 Series  328i SULEV  Sedan    automatic
# 3 2015-01-01  Volvo                  S60          T5  Sedan    automatic
# 4 2014-01-01    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
#trend of selling price over years
plt.figure(figsize=(5,5))
sns.lineplot(x='year',y= 'sellingprice', data=data,label='Selling price')
sns.lineplot(x='year',y= 'mmr', data=data,label='mmr')
plt.title('Selling Price Trend')
plt.ylabel=('Wams')
plt.legend()

plt.show()

# %% [markdown]
# #### Trend of car prices for the top ten brands...

# %%
top_ten=data['make'].value_counts().nlargest(10).index
top_ten
# Out:
# Index(['Ford', 'Chevrolet', 'Nissan', 'Toyota', 'Dodge', 'Honda', 'Hyundai',
#        'BMW', 'Kia', 'Chrysler'],
#       dtype='object', name='make')

# %%
top_ten_cars=data[data['make'].isin(top_ten)]

# %%
top_ten_cars.head()
# Out:
#         year    make                model        trim   body transmission  \
# 0 2015-01-01     Kia              Sorento          LX    SUV    automatic
# 1 2015-01-01     Kia              Sorento          LX    SUV    automatic
# 2 2014-01-01     BMW             3 Series  328i SULEV  Sedan    automatic
# 4 2014-01-01     BMW  6 Series Gran Coupe        650i  Sedan    automatic
# 5 2015-01-01  Nissan               Altima       2.5 S  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
# 5  1n4al3ap1fn326013    ca        1.0    5554.0   gray    black
#
#                                               seller      mmr  sellingprice  \
# ...

# %%
plt.figure(figsize=(12,5))
sns.lineplot(data=top_ten_cars, x='year',y='sellingprice',hue='make')
plt.title('Selling Price Trends of Top 10 Car Brands')
plt.ylabel('Selling Price in USD')
plt.xlabel('YEAR')
plt.legend(loc='lower center', ncol=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 4
#       2 sns.lineplot(data=top_ten_cars, x='year',y='sellingprice',hue='make')
#       3 plt.title('Selling Price Trends of Top 10 Car Brands')
# ----> 4 plt.ylabel('Selling Price in USD')
#       5 plt.xlabel('YEAR')
#       6 plt.legend(loc='lower center', ncol=5)
#
# TypeError: 'str' object is not callable

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=top_ten_cars, x='make')
# Out:
# <Axes: xlabel='make', ylabel='count'>

# %%
car_popularity=data['make'].value_counts().reset_index()
car_popularity
# Out:
#           make  count
# 0         Ford  93554
# 1    Chevrolet  60197
# 2       Nissan  53946
# 3       Toyota  39871
# 4        Dodge  30710
# ..         ...    ...
# 91   airstream      1
# 92     ford tk      1
# 93  chev truck      1
# 94  hyundai tk      1
# 95       Lotus      1
#
# [96 rows x 2 columns]

# %%
plt.figure(figsize=(20,5))
sns.barplot(data=car_popularity,x='make',y='count')
plt.xticks(rotation=90)
#plt.ylabel('Car Brand')
#plt.xlabel('Units Sold')

plt.show()

# %%
body_names=data['body'].value_counts().nlargest(5).index

# %%
top_5_body=data[data['body'].isin(body_names)]

# %%
#top_5_body.head()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=top_5_body, x='year',hue='body',palette='viridis')
plt.xticks(rotation=90)
plt.gca().invert_xaxis()
plt.show()

# %% [markdown]
# ### Trends in Vehicle Condition over time

# %% [markdown]
# ### Trends in Odometer over time

# %%
#correlation=data[['condition','odometer','mmr','sellingprice','Age at Sale']].corr()

# %%
#sns.heatmap(correlation,annot=True)

# %%
#target = data['make'].value_counts().nlargest(3).index

# %%
#filt_df = data[data['make'].isin(target)]

# %%
#filt_df
# Out:
#              year       make           model    trim         body  \
# 5      2015-01-01     Nissan          Altima   2.5 S        Sedan
# 7      2014-01-01  Chevrolet           Cruze     1LT        Sedan
# 9      2014-01-01  Chevrolet          Camaro      LT  Convertible
# 12     2015-01-01       Ford          Fusion      SE        Sedan
# 14     2014-01-01  Chevrolet           Cruze     2LT        Sedan
# ...           ...        ...             ...     ...          ...
# 558821 2012-01-01       Ford          Escape     XLT          SUV
# 558823 2012-01-01  Chevrolet  Silverado 1500      LT     Crew Cab
# 558830 2012-01-01     Nissan          Sentra  2.0 SR        Sedan
# 558835 2015-01-01     Nissan          Altima   2.5 S        sedan
# 558836 2014-01-01       Ford           F-150     XLT    SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 5         automatic  1n4al3ap1fn326013    ca        1.0    5554.0   gray
# ...

# %%
#sns.scatterplot(data=filt_df,x='odometer',y='sellingprice',hue='make')
#plt.show()

# %%
sns.scatterplot(data=filt_df,x='odometer',y='mmr',hue='make')
plt.show()

# %%
sns.scatterplot(data=filt_df,x='sellingprice',y='mmr',hue='make')
plt.show()

# %%
sns.kdeplot(x='sellingprice',data=filt_df,hue='make',fill=True)
# Out:
# <Axes: xlabel='sellingprice', ylabel='Density'>

# %% [markdown]
# **How is the distribution of car conditions?**

# %% [markdown]
# **What is the average odometer reading by make and model?**

# %% [markdown]
# **How do selling prices vary by car make?**

# %% [markdown]
# **What is the most common car color?**

# %% [markdown]
# **How does the distribution of odometer readings differ between new and used cars?**

# %% [markdown]
# **Is there a correlation between odometer reading and selling price?**

# %% [markdown]
# **What is the monthly trend in car sales?**

# %% [markdown]
# **How does the average selling price vary over the years?**

# %% [markdown]
# **Which states have the highest number of car sales?**

# %% [markdown]
# **What is the distribution of car transmission types?**
